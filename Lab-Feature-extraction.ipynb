# %%
#Instructions

# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\Usuari\Downloads\we_fn_use_c_marketing_customer_value_analysis (1).csv")

# %%
data.iloc[0]
# Out:
# Customer                                BU79786
# State                                Washington
# Customer Lifetime Value             2763.519279
# Response                                     No
# Coverage                                  Basic
# Education                              Bachelor
# Effective To Date                       2/24/11
# EmploymentStatus                       Employed
# Gender                                        F
# Income                                    56274
# Location Code                          Suburban
# Marital Status                          Married
# Monthly Premium Auto                         69
# Months Since Last Claim                      32
# Months Since Policy Inception                 5
# Number of Open Complaints                     0
# Number of Policies                            1
# Policy Type                      Corporate Auto
# Policy                             Corporate L3
# Renew Offer Type                         Offer1
# ...

# %%
#1 Open the categorical variables:

# %%
categoricals = data.select_dtypes(include='object')
categoricals.head()
# Out:
#   Customer       State Response  Coverage Education Effective To Date  \
# 0  BU79786  Washington       No     Basic  Bachelor           2/24/11
# 1  QZ44356     Arizona       No  Extended  Bachelor           1/31/11
# 2  AI49188      Nevada       No   Premium  Bachelor           2/19/11
# 3  WW63253  California       No     Basic  Bachelor           1/20/11
# 4  HB64268  Washington       No     Basic  Bachelor            2/3/11
#
#   EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# 0         Employed      F      Suburban        Married  Corporate Auto
# 1       Unemployed      F      Suburban         Single   Personal Auto
# 2         Employed      F      Suburban        Married   Personal Auto
# 3       Unemployed      M      Suburban        Married  Corporate Auto
# 4         Employed      M         Rural         Single   Personal Auto
#
#          Policy Renew Offer Type Sales Channel  Vehicle Class Vehicle Size
# ...

# %%
#2 Plot all the categorical variables with the proper plot. What can you see?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Plotting categorical variables
for column in categoricals.columns:
    plt.figure(figsize=(18, 12))
    sns.countplot(x=column, data=categoricals, order=categoricals[column].value_counts().index)
    plt.title(f'Distribution of {column}')
    plt.xticks(rotation=45)
    plt.show()

# %%
# 3 There might be some columns that seem to be redundant, check their values to be sure. What should we do with them?

# %%
for column in categoricals.columns:
    print(f"Unique values in {column}: {categoricals[column].unique()}")
# Out:
# Unique values in Customer: ['BU79786' 'QZ44356' 'AI49188' ... 'TD14365' 'UP19263' 'Y167826']
# Unique values in State: ['Washington' 'Arizona' 'Nevada' 'California' 'Oregon']
# Unique values in Response: ['No' 'Yes']
# Unique values in Coverage: ['Basic' 'Extended' 'Premium']
# Unique values in Education: ['Bachelor' 'College' 'Master' 'High School or Below' 'Doctor']
# Unique values in Effective To Date: ['2/24/11' '1/31/11' '2/19/11' '1/20/11' '2/3/11' '1/25/11' '1/18/11'
#  '1/26/11' '2/17/11' '2/21/11' '1/6/11' '2/6/11' '1/10/11' '1/17/11'
#  '1/5/11' '2/27/11' '1/14/11' '1/21/11' '2/5/11' '1/29/11' '2/28/11'
#  '2/12/11' '2/2/11' '2/7/11' '1/22/11' '2/13/11' '1/15/11' '1/8/11'
#  '1/11/11' '1/28/11' '2/8/11' '2/23/11' '1/2/11' '2/16/11' '1/27/11'
#  '1/23/11' '1/9/11' '2/11/11' '2/4/11' '2/1/11' '2/15/11' '2/26/11'
#  '1/16/11' '1/1/11' '2/10/11' '1/24/11' '2/25/11' '1/12/11' '2/9/11'
#  '1/19/11' '1/4/11' '2/14/11' '2/20/11' '2/18/11' '1/3/11' '1/13/11'
# ...

# %%
# Eliminar la columna "Policy Type"
categoricals.drop(columns=['Policy Type'], inplace=True)

# %%
categoricals
# Out:
#      Customer       State Response  Coverage Education Effective To Date  \
# 0     BU79786  Washington       No     Basic  Bachelor           2/24/11
# 1     QZ44356     Arizona       No  Extended  Bachelor           1/31/11
# 2     AI49188      Nevada       No   Premium  Bachelor           2/19/11
# 3     WW63253  California       No     Basic  Bachelor           1/20/11
# 4     HB64268  Washington       No     Basic  Bachelor            2/3/11
# ...       ...         ...      ...       ...       ...               ...
# 9129  LA72316  California       No     Basic  Bachelor           2/10/11
# 9130  PK87824  California      Yes  Extended   College           2/12/11
# 9131  TD14365  California       No  Extended  Bachelor            2/6/11
# 9132  UP19263  California       No  Extended   College            2/3/11
# 9133  Y167826  California       No  Extended   College           2/14/11
#
#      EmploymentStatus Gender Location Code Marital Status        Policy  \
# ...

# %%
# 4 Plot time variable. Can you extract something from it?

# %%
plt.figure(figsize=(30, 15))
sns.lineplot(x='Effective To Date', y='Coverage', data=data)
plt.title("Effective To Date vs. Coverage")
plt.ylabel('Coverage')
plt.show()

# %%
# Convertir la columna "Effective To Date" a tipo de dato datetime
data['Effective To Date'] = pd.to_datetime(data['Effective To Date'])

# Extraer el mes de cada fecha y crear una nueva columna llamada "Month"
data['Month'] = data['Effective To Date'].dt.month

# Verificar los resultados
print(data[['Effective To Date', 'Month']].head())
# Out:
#   Effective To Date  Month
# 0        2011-02-24      2
# 1        2011-01-31      1
# 2        2011-02-19      2
# 3        2011-01-20      1
# 4        2011-02-03      2
# C:\Users\Usuari\AppData\Local\Temp\ipykernel_24724\3740179595.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Effective To Date'] = pd.to_datetime(data['Effective To Date'])

# %%
data
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
plt.figure(figsize=(35, 15))
sns.lineplot(x='Month', y='Coverage', data=data)
plt.title("Month vs. Coverage")
plt.ylabel('Coverage')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Crear datos de ejemplo
data = pd.DataFrame({
    'Month': pd.date_range(start='2022-01-01', end='2022-12-31', freq='D'),
    'Coverage': range(365)
})

# Ajustar el tamaño del gráfico
plt.figure(figsize=(10, 6))

# Trama el gráfico de líneas
sns.lineplot(x='Month', y='Coverage', data=data)

# Configurar el título y las etiquetas de los ejes
plt.title("Mes vs. Cobertura")
plt.ylabel('Cobertura')
plt.xlabel('Mes')

# Ajustar los límites y las ubicaciones de las etiquetas del eje x
plt.xticks(pd.date_range(start='2022-01-01', end='2022-12-31', freq='M'), 
           [date.strftime('%Y-%m-%d') for date in pd.date_range(start='2022-01-01', end='2022-12-31', freq='M')], 
           rotation=45)

# Mostrar el gráfico
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Usuari\AppData\Local\Temp\ipykernel_24724\3803368644.py:23: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   plt.xticks(pd.date_range(start='2022-01-01', end='2022-12-31', freq='M'),
# C:\Users\Usuari\AppData\Local\Temp\ipykernel_24724\3803368644.py:24: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   [date.strftime('%Y-%m-%d') for date in pd.date_range(start='2022-01-01', end='2022-12-31', freq='M')],
